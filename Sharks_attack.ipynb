# %% [markdown]
# # HIPÓTESIS A CONFIRMAR SHARK'S ATTACKS

# %%
#Primer paso importar los módulos correspondientes 
import pandas as pd
import numpy as np
import re

# %%
#Obtengo el data set para poder trabajar con el en pandas
data = pd.read_csv(r"./Input/attacks.csv", encoding='latin-1')

# %%
#Realizo el shape para conocer las dimensiones del dataframe
data.shape
# Out:
# (25723, 24)

# %%
#Aquí tengo la información sobre las columnas
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#Observo el número de nulos por columna para saber con que columnas me quiero quedar
data.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 22               25722
# Unnamed: 23               25721
# Time                      22775
# Species                   22259
# Age                       22252
# Sex                       19986
# Activity                  19965
# Location                  19961
# Fatal (Y/N)               19960
# Area                      19876
# Name                      19631
# Country                   19471
# Injury                    19449
# Investigator or Source    19438
# Type                      19425
# Year                      19423
# href formula              19422
# pdf                       19421
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# Date                      19421
# original order            19414
# Case Number               17021
# dtype: int64

# %% [markdown]
# # Aquí realizo la primera limpieza de columnas que no me van a aportar información a mi hipótesis

# %%
#Quito las columnas de Unnamed 22 y 23 que no contienen datos
adata = data[['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order']]

# %%
adata.shape
# Out:
# (25723, 22)

# %%
adata.isnull().sum().sort_values(ascending=False)
# Out:
# Time                      22775
# Species                   22259
# Age                       22252
# Sex                       19986
# Activity                  19965
# Location                  19961
# Fatal (Y/N)               19960
# Area                      19876
# Name                      19631
# Country                   19471
# Injury                    19449
# Investigator or Source    19438
# Type                      19425
# Year                      19423
# href formula              19422
# Case Number.2             19421
# Date                      19421
# pdf                       19421
# href                      19421
# Case Number.1             19421
# original order            19414
# Case Number               17021
# dtype: int64

# %%
#Para eliminar filas vacías que no me van a aportar nada de información, utilizo la función dropna
bdata = adata.dropna(
    axis=0,
    how='all',
    thresh=None,
    subset=None,
    inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-6abb623f0512> in <module>
#       1 #Para eliminar filas vacías que no me van a aportar nada de información, utilizo la función dropna
# ----> 2 bdata = adata.dropna(
#       3     axis=0,
#       4     how='all',
#       5     thresh=None,
#
# NameError: name 'adata' is not defined

# %%
#Vuelvo a comprobar el número de filas...
bdata.shape

# %%
#..y vuelvo a comprobar también los null por columna
bdata.isnull().sum().sort_values(ascending=False)
# Out:
# Time                      5755
# Species                   5239
# Age                       5232
# Sex                       2966
# Activity                  2945
# Location                  2941
# Fatal (Y/N)               2940
# Area                      2856
# Name                      2611
# Country                   2451
# Injury                    2429
# Investigator or Source    2418
# Type                      2405
# Year                      2403
# href formula              2402
# Case Number.2             2401
# Date                      2401
# pdf                       2401
# href                      2401
# Case Number.1             2401
# original order            2394
# Case Number                  1
# dtype: int64

# %% [markdown]
# ### Compruebo los valores de las siguientes columnas observando que me dan el mismo tipo de información

# %%
#Comprobaciones
#cdata['Case Number']
#cdata['Case Number.1']
#cdata['Case Number.2']
#cdata['Date'])

# %%
bdata['Date']
# Out:
# 0        25-Jun-2018
# 1        18-Jun-2018
# 2        09-Jun-2018
# 3        08-Jun-2018
# 4        04-Jun-2018
#             ...
# 8698             NaN
# 8699             NaN
# 8700             NaN
# 8701             NaN
# 25722            NaN
# Name: Date, Length: 8703, dtype: object

# %%
cdata = bdata[['Date', 'Year', 'Type', 'Country', 'Area', 'Location',
        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'original order']]

# %%
cdata['Age'].value_counts()

# %%
cdata['Species ']

# %%
cdata.isnull().sum()

# %%
ddata = cdata.dropna(
    axis=0,
    how='all',
    thresh=None,
    subset=None,
    inplace=False)

# %%
ddata.shape
# Out:
# (8703, 22)

# %%
ddata

# %%
ddata.isnull().sum().sort_values(ascending=False)

# %%
#finaldata.fillna(self, value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)

# %% [markdown]
#    # Hago selección de las columnas con las que voy a trabajar para probar la hipótesis

# %%
edata = ddata[['Date', 'Year', 'Type', 'Country', 'Area', 'Location',
        'Activity', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Species ']]

# %%
#De nuevo, limpio las filas que sólo contengan nulls
finaldata = edata.dropna(
    axis=0,
    how='all',
    thresh=None,
    subset=None,
    inplace=False)

# %%
finaldata.shape
# Out:
# (6302, 14)

# %%
finaldata.isnull().sum()
# Out:
# Date              0
# Year            889
# Type              4
# Country          50
# Area            455
# Location        540
# Activity        544
# Sex             565
# Age            2831
# Injury           28
# Fatal (Y/N)     539
# Species        2838
# Day               0
# Month           518
# dtype: int64

# %%
datesp = edata['Date'].str.split('-')

# %%
edata['Day']=datesp.str.get(0)
edata['Month']=datesp.str.get(1)
edata['Year']=datesp.str.get(2)
# Out:
# <ipython-input-38-cd4eeb7c52f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edata['Day']=datesp.str.get(0)
# <ipython-input-38-cd4eeb7c52f8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edata['Month']=datesp.str.get(1)
# <ipython-input-38-cd4eeb7c52f8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ##### Las columnas de Age, Time y Species no me ofrecen tanta información  respecto al resto de columnas

# %%
perccountry = finaldata['Country'].value_counts()/(6309-57)*100
perccountry.head(20)

# %%
finaldata[['Day','Month','Year']]
for e in finaldata['Day']:
    print(e)
# Out:
# 25
# 18
# 09
# 08
# 04
# 03
# 03
# 27
# 26
# 26
# 24
# 21
# 13
# 13
# May 2018
# 12
# 09
# Reported 30
# 28
# 28
# 25
# 25
# 24
# 23
# 22
# 19
# 15
# 15
# 15
# 15
# 14
# Reported 10
# 09
# 05
# 03
# 31
# 14
# 9
# 9
# 24
# 23
# 18
# 15
# 14
# 11
# 03
# 01
# 28
# 21
# 14
# 13
# 12
# 05
# 31
# 30
# 21
# 09
# 30
# 30
# Reported 25
# 24
# 18
# Reported 13
# 13
# 04
# Reported 31
# 28
# 26
# 23
# 23
# 23
# 22
# 21
# 18
# 09
# 05
# 01
# 25
# 25
# 24
# 24
# 20
# 16
# 16
# 15
# 15
# Sep
# 13
# 10
# 10
# Reported 06
# 03
# 03
# 02
# 02
# 02
# 29
# 27
# 26
# 26
# 23
# 18
# 10
# 05
# 03
# 01
# 31
# 29
# 29
# 27
# Reported 26
# 24
# 23
# 23
# 22
# 20
# 20
# 20
# 14
# 14
# 11
# 09
# Reported 07
# 07
# 02
# 29
# 21
# 19
# 18
# 18
# 17
# 2017.06.05
# Reported 14
# 11
# 10
# 10
# Reported 07
# 04
# 02
# 30
# 28
# 27
# 12
# Reported 06
# 05
# 03
# 29
# 29
# 29
# 29
# 27
# 26
# 22
# 20
# 17
# 17
# 14
# 13
# 12
# 12
# 11
# 10
# 10
# 06
# 05
# 02
# 02
# 27
# 19
# 18
# 11
# Reported 09
# 25
# 24
# 21
# ...

# %%
#finaldata.loc[finaldata['Year']>1000,['Year']]

# %%
finaldata['Injury'] = finaldata.Injury.fillna("")
def noinjury(e):
for e in finaldata['Injury']:
    print(e)
    non= re.findall(r'(No|no)\s\w+',e)
    print(non)
    return str()
# Out:
# <ipython-input-64-d38b69d77e3f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldata['Injury'] = finaldata.Injury.fillna("")
# No injury to occupant, outrigger canoe and paddle damaged
# ['No']
# Minor injury to left thigh
# []
# Injury to left lower leg from surfboard skeg
# []
# Minor injury to lower leg
# []
# Lacerations to leg & hand shark PROVOKED INCIDENT
# []
# No injury, board bitten
# ['No']
# FATAL
# []
# Minor injury to foot. PROVOKED INCIDENT
# []
# Lower left leg bitten
# []
# Minor injury to foot
# []
# Minor bite to hand by captive shark. PROVOKED INCIDENT
# []
# Injuries to lower right leg and foot
# []
# Severe bite to right forearm
# []
# Injured by teeth of a dead porbeagle shark he was tossing overboard.
# []
# ...

# %%
df_clean["tipo_trany_2"] = df_clean.trany
df_clean["tipo_trany_2"][df_clean.trany.str.startswith("A")] = "Automatico"
df_clean["tipo_trany_2"][df_clean.trany.str.startswith("M")] = "Manual"

# %%
finaldata.groupby("Year").agg({"Injury":"count"})

# %%
a = finaldata.groupby(["Year","Type"]).agg({"Type":"count"})
a

# %%
finaldata['Fatal (Y/N)'].value_counts()

# %%
finaldata['Fatal (Y/N)'].fillna('UNKNOWN')

# %%
finaldata['Fatal (Y/N)'].value_counts()

# %%
finaldata['Fatal (Y/N)'].isnull().count()

# %%
finaldata['Age'].value_counts().sum()
